# %% [markdown]
# # Scientific Text Classification

# %% [markdown]
# @author: Tyler Bikaun

# %% [markdown]
# 1. Use labelled datasets to predict unlabelled datasets
# 2. Need to concatenate labels together where there are multiple fields of study

# %%
import pandas as pd
import re
import numpy as np
import ast

# %% [markdown]
# ## Mounting drive to access model data

# %% [raw]
# # Mount google drive to notebook to access data.
# # This will prompt you to enter an authentication code by permitting access to the drive.
# from google.colab import drive
# drive.mount('/content/drive')

# %%
class Data():
    
    def __init__(self, fileName):
        
        self.dataOriginal = pd.read_csv(fileName)
        self.data = self.dataOriginal.copy()
        self.lenOriginalData = len(self.data)
        
        # exe
        self.formatData()
        self.formatLabelData()
        self.dropNanText()
        self.removeDataWithoutLabels()
    
    def formatData(self):
        # subset data for title, abstract, field of study
        self.data = self.data[['Unnamed: 0', '0', '2']]
        # rename columns
        self.data.rename(columns={'Unnamed: 0': 'title', '0': 'abstract', '2':'label'}, inplace=True)
        # Replace NaN
        self.data['abstract'] = self.data['abstract'].replace(np.nan, '', regex=True)
        # concatenate title and abstract
        self.data['text'] = self.data['title'] + ' ' + self.data['abstract']
        # Drop unnecessary columns
        self.data.drop(labels=['title', 'abstract'], axis=1, inplace=True)
        # change order of columns
        self.data = self.data[['label', 'text']]
        # Concatenate labels
        self.data['label'] = self.data['label'].apply(lambda x: self.labelConcat(x))
    
    def labelConcat(self, labelText):
        # Political Science should be made into Political-Science?
        try:
            return ''.join(ast.literal_eval(labelText))
        except:
            return ''
    
    def formatLabelData(self):
        """
        Format labels with FastText style
        """
        
        # Add '__label__' to label text data for Flair model
        self.data['label'] = '__label__' + self.data['label']
        
    def dropNanText(self):
        # drop any text that is NaN
        # Note: Might need to extend this to be just applicable to the abtract.
        self.data.dropna()

    def dataSummary(self):
        print(f'Rows dropped: {self.lenOriginalData - len(self.data)}')
        
    def removeDataWithoutLabels(self):
        self.dataNoLabel = self.data[self.data['label'] == '__label__']
        # print(self.data['text'])
        self.data = self.data[self.data['label'] != '__label__']

# %%
tcDataCS = Data(r"C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/papers_of_interest.csv")

# %%
tcDataCS.dataSummary()
# Out:
# Rows dropped: 0

# %%
tcDataCS.dataOriginal
# Out:
#                                               Unnamed: 0  \
# 0                 Texture synthesis for digital painting
# 1      Texture analysis and artificial neural network...
# 2      Automatic generation of benchmark and test wor...
# 3                               Text Encoding Initiative
# 4      A Method of Text Classification Combining Naiv...
# ...                                                  ...
# 29865  Texture discrimination using local features an...
# 29866                 Information Retrieval in the Cloud
# 29867  TExtractor: An OSINT Tool to Extract and Analy...
# 29868  Text retrieval: A directory of software : R. K...
# 29869  Identification clouds: aspects of the implemen...
#
#                                                        0     1  \
# 0      The problem of digital painting is considered ...  1984
# 1      Clustered microcalcifications on X-ray mammogr...  1997
# 2      In this tutorial, we describe techniques for a...  2010
# 3      This paper traces the history of the Text Enco...  1995
# 4      Text classification is one of the main issues ...  2015
# ...                                                  ...   ...
# 29865  In this paper we consider the problem of textu...  2011
# 29866  There has been a recent trend to migrate IT in...  2018
# 29867  Hacking, data breaches, and information loss a...  2018
# 29868                                                NaN  1988
# 29869  textabstractThis note is concerned with the au...  2005
#
#                           2  \
# 0      ['Computer Science']
# 1      ['Computer Science']
# 2      ['Computer Science']
# 3      ['Computer Science']
# 4      ['Computer Science']
# ...                     ...
# 29865  ['Computer Science']
# 29866  ['Computer Science']
# 29867  ['Computer Science']
# 29868  ['Computer Science']
# 29869  ['Computer Science']
#
#                                                        3  \
# 0                                                    NaN
# 1      Neural Networks for Signal Processing VII. Pro...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29865  2011 International Conference on Communication...
# 29866                                              ArXiv
# 29867                                                NaN
# 29868                                                NaN
# 29869                                                NaN
#
#                                                        4   5   6
# 0      https://semanticscholar.org/paper/1e9c964d606e...  63  10
# 1      https://semanticscholar.org/paper/b283fccfdeef...   3   9
# 2      https://semanticscholar.org/paper/b56c5cac50dd...   6   8
# 3      https://semanticscholar.org/paper/ee77bdaf4841...  16  10
# 4      https://semanticscholar.org/paper/195e933e65ed...   0   0
# ...                                                  ...  ..  ..
# 29865  https://semanticscholar.org/paper/1efa4eb7fa3b...   2  29
# 29866  https://semanticscholar.org/paper/f9b6e9cec75d...   0  16
# 29867  https://semanticscholar.org/paper/70760bd5b455...   0   0
# 29868  https://semanticscholar.org/paper/977bb681585c...   0   0
# 29869  https://semanticscholar.org/paper/2a1974cb5d3b...   0   4
#
# [29870 rows x 8 columns]

# %%
tcDataCS.data
# Out:
#                            label  \
# 0      __label__Computer Science
# 1      __label__Computer Science
# 2      __label__Computer Science
# 3      __label__Computer Science
# 4      __label__Computer Science
# ...                          ...
# 29865  __label__Computer Science
# 29866  __label__Computer Science
# 29867  __label__Computer Science
# 29868  __label__Computer Science
# 29869  __label__Computer Science
#
#                                                     text
# 0      Texture synthesis for digital painting The pro...
# 1      Texture analysis and artificial neural network...
# 2      Automatic generation of benchmark and test wor...
# 3      Text Encoding Initiative This paper traces the...
# 4      A Method of Text Classification Combining Naiv...
# ...                                                  ...
# 29865  Texture discrimination using local features an...
# 29866  Information Retrieval in the Cloud There has b...
# 29867  TExtractor: An OSINT Tool to Extract and Analy...
# 29868  Text retrieval: A directory of software : R. K...
# 29869  Identification clouds: aspects of the implemen...
#
# [29870 rows x 2 columns]

# %%
tcDataCS.data['text'][0]
# Out:
# 'Texture synthesis for digital painting The problem of digital painting is considered from a signal processing viewpoint, and is reconsidered as a problem of directed texture synthesis. It is an important characteristic of natural texture that detail may be evident at many scales, and the detail at each scale may have distinct characteristics. A “sparse convolution” procedure for generating random textures with arbitrary spectral content is described. The capability of specifying the texture spectrum (and thus the amount of detail at each scale) is an improvement over stochastic texture synthesis processes which are scalebound or which have a prescribed 1/f spectrum. This spectral texture synthesis procedure provides the basis for a digital paint system which rivals the textural sophistication of traditional artistic media. Applications in terrain synthesis and texturing computer-rendered objects are also shown.'

# %%
tcDataCS.data.head()
# Out:
#                        label  \
# 0  __label__Computer Science
# 1  __label__Computer Science
# 2  __label__Computer Science
# 3  __label__Computer Science
# 4  __label__Computer Science
#
#                                                 text
# 0  Texture synthesis for digital painting The pro...
# 1  Texture analysis and artificial neural network...
# 2  Automatic generation of benchmark and test wor...
# 3  Text Encoding Initiative This paper traces the...
# 4  A Method of Text Classification Combining Naiv...

# %% [markdown]
# ### Other datasets

# %%
tcDataOther = Data(r"C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/papers_NOT_of_interest.csv")

# %%
# Must be due to the NaN values for abstracts.
tcDataOther.dataSummary()
# Out:
# Rows dropped: 7239

# %%
tcDataOther.dataOriginal
# Out:
#                                               Unnamed: 0  \
# 0      Use and Safety of Respiratory Medicines in Chi...
# 1      Language in Australia: Transplanted languages ...
# 2      Automatic Generation of A High-level Contact S...
# 3      Textured Thin Films of Transition Metal Dichal...
# 4      Text Mining with Support Vector Machines and N...
# ...                                                  ...
# 51808  An Analysis on the Economy Development Situati...
# 51809  The Heidelberg iterative cloud retrieval utili...
# 51810  Replacement Automatic Preprocessing Case Base ...
# 51811  Text-Perplexed? et Hallaou!. Festival Voix d’A...
# 51812  Text as Sliding Signifier: Correcting the Slip...
#
#                                                        0     1  \
# 0      textabstractThe lack of appropriately authoris...  2011
# 1                                                    NaN  1991
# 2      Information of high-level, topological contact...  2007
# 3                                                    NaN  1994
# 4      The objective of this thesis is to develop eff...  2007
# ...                                                  ...   ...
# 51808  Textile industry is the traditional and crucia...  2004
# 51809  Information about clouds, in particular the ac...  2006
# 51810  Natural Language Generation (NLG) is one of th...  2012
# 51811                                                NaN  2007
# 51812  In the 1980s Ricoeur conceptualized metaphoric...  2015
#
#                            2
# 0               ['Medicine']
# 1              ['Sociology']
# 2            ['Engineering']
# 3      ['Materials Science']
# 4                         []
# ...                      ...
# 51808        ['Engineering']
# 51809          ['Chemistry']
# 51810                     []
# 51811                     []
# 51812         ['Philosophy']
#
# [51813 rows x 4 columns]

# %%
# print(tcDataOther.data.to_string())

# %%
tcDataOther.lenOriginalData
# Out:
# 51813

# %%
len(tcDataOther.data)
# Out:
# 44574

# %%
len(tcDataOther.dataNoLabel)
# Out:
# 7239

# %%
tcDataOther.dataNoLabel
# Out:
#            label                                               text
# 4      __label__  Text Mining with Support Vector Machines and N...
# 15     __label__  Textschicksale: Das Werk Arthur Schnitzlers im...
# 22     __label__  Text-Kultur Kommunikation : Translation als Fo...
# 30     __label__  Textual Features from Multimedia Conten Identi...
# 45     __label__  Language contact and language change – linguis...
# ...          ...                                                ...
# 51786  __label__  Texto y contexto de la STJUE sobre indemnizaci...
# 51801  __label__                   Texture 영상분할을 위한 고속 적응 특징 추출 방법
# 51803  __label__  Texture Features for Image Retrieval using Wav...
# 51810  __label__  Replacement Automatic Preprocessing Case Base ...
# 51811  __label__  Text-Perplexed? et Hallaou!. Festival Voix d’A...
#
# [7239 rows x 2 columns]

# %% [markdown]
# ### Create entire dataset

# %%
trainingData = tcDataCS.data.append(tcDataOther.data)

# %%
trainingData.head()
# Out:
#                             label  \
# 0       __label__Computer Science
# 1       __label__Computer Science
# 2       __label__Computer Science
# 3       __label__Computer Science
# 4       __label__Computer Science
# ...                           ...
# 51806  __label__Political Science
# 51807        __label__Mathematics
# 51808        __label__Engineering
# 51809          __label__Chemistry
# 51812         __label__Philosophy
#
#                                                     text
# 0      Texture synthesis for digital painting The pro...
# 1      Texture analysis and artificial neural network...
# 2      Automatic generation of benchmark and test wor...
# 3      Text Encoding Initiative This paper traces the...
# 4      A Method of Text Classification Combining Naiv...
# ...                                                  ...
# 51806  Textes de politique internationale depuis 1945...
# 51807  Natural convection at a heated semiinfinite ve...
# 51808  An Analysis on the Economy Development Situati...
# 51809  The Heidelberg iterative cloud retrieval utili...
# 51812  Text as Sliding Signifier: Correcting the Slip...
#
# [74444 rows x 2 columns]

# %% [markdown]
# #### Test, Dev, Train Split

# %%
# attr: https://stackoverflow.com/questions/38250710/how-to-split-data-into-3-sets-train-validation-and-test
train, dev, test = np.split(trainingData.sample(frac=1), [int(.6*len(trainingData)), int(.8*len(trainingData))])
print(f'{len(trainingData)} | {len(train)} | {len(dev)} | {len(test)}')
# Out:
# 74444 | 44666 | 14889 | 14889

# %%
train.to_csv(r'C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/train.csv', sep='\t', index = False, header = False)
test.to_csv(r'C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/test.csv', sep='\t', index = False, header = False)
dev.to_csv(r'C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/dev.csv', sep='\t', index = False, header = False)

# %% [markdown]
# Review data to ensure it's been saved correctly.

# %%
dev = pd.read_csv('C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/dev.csv', sep='\t')

# %%
dev.head()
# Out:
#                 __label__Art  \
# 0  __label__Computer Science
# 1  __label__Computer Science
# 2  __label__Computer Science
# 3        __label__Psychology
# 4        __label__Psychology
#
#          Texto Refundido de Régimen Local: Art. 368
# 0  Automatic Timeiseries Model Generation for Rea...
# 1  Text-based English-Arabic sentence alignment I...
# 2  Natural language interaction with an expert sy...
# 3        Language use and language learning in CLIL
# 4  Auditieve hersenstampotentialen bij de mens : ...

# %% [markdown]
# ## Flair Text Classification

# %% [markdown]
# https://towardsdatascience.com/text-classification-with-state-of-the-art-nlp-library-flair-b541d7add21f

# %% [raw]
# !pip install flair

# %% [markdown]
# ### Create corpus

# %%
from flair.data_fetcher import NLPTaskDataFetcher
from flair.embeddings import WordEmbeddings, FlairEmbeddings, DocumentLSTMEmbeddings
from flair.models import TextClassifier
from flair.trainers import ModelTrainer
from pathlib import Path

import flair, torch

# Use GPU if available - Having issues with Flair model with GPU; switched to CPU for now.
device = None
# if torch.cuda.is_available():
#     device = torch.device('cuda:0')
# else:
#     device = torch.device('cpu')
device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %%
flair.device = torch.device('cpu')

# %%
flair.device
# Out:
# device(type='cpu')

# %%
corpus = NLPTaskDataFetcher.load_classification_corpus(Path('C:/Users/Tyler/Desktop/UWA Repos/literaturesieve/project/notebooks/data/'),
                                                       test_file='test.csv',
                                                       dev_file='dev.csv',
                                                       train_file='train.csv')
# Out:
# c:\users\tyler\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated function (or staticmethod) load_classification_corpus. (Use 'flair.datasets' instead.) -- Deprecated since version 0.4.1.
#   after removing the cwd from sys.path.
# 2020-04-09 11:37:59,778 Reading data from C:\Users\Tyler\Desktop\UWA Repos\literaturesieve\project\notebooks\data
# 2020-04-09 11:37:59,779 Train: C:\Users\Tyler\Desktop\UWA Repos\literaturesieve\project\notebooks\data\train.csv
# 2020-04-09 11:37:59,780 Dev: C:\Users\Tyler\Desktop\UWA Repos\literaturesieve\project\notebooks\data\dev.csv
# 2020-04-09 11:37:59,782 Test: C:\Users\Tyler\Desktop\UWA Repos\literaturesieve\project\notebooks\data\test.csv

# %%
print(len(corpus.train))
# Out:
# 44666

# %%
corpus.make_label_dictionary()
# Out:
# 2020-04-09 11:42:57,075 Computing label dictionary. Progress:
# 100%|█████████████████████████████████████████████████████████████████████████| 44666/44666 [00:00<00:00, 95491.31it/s]
# 2020-04-09 11:42:57,715 [b'Mathematics', b'Computer', b'Business', b'Materials', b'Geology', b'Art', b'Geography', b'Medicine', b'Psychology', b'Engineering', b'Biology', b'History', b'Environmental', b'Philosophy', b'EngineeringComputer', b'SociologyPhilosophy', b'Economics', b'Sociology', b'Political', b'Chemistry', b'ChemistryMedicine', b'Physics', b'PsychologyMedicine', b'MathematicsComputer', b'BiologyMedicine', b'GeographyMedicine', b'MedicineComputer', b'MedicineChemistry', b'MedicineEngineering', b'MedicineMathematicsComputer', b'MathematicsEngineering', b'SociologyMedicine', b'SociologyComputer', b'MedicinePhysics', b'PhysicsMedicine', b'PhysicsComputer', b'ChemistryPhysics', b'MedicineBiology', b'SociologyGeography', b'EconomicsMathematics', b'SociologyMedicineComputer', b'MedicineMathematics', b'MathematicsMedicine', b'PsychologyComputer', b'MedicineMaterials', b'EconomicsGeography', b'EngineeringGeography', b'EngineeringMathematics', b'GeologyMedicine', b'PsychologyArt', b'ChemistryComputer', b'GeographyEngineering', b'GeographyBiology', b'EconomicsPolitical', b'PhysicsEngineering', b'BusinessMathematics', b'GeologyGeography', b'GeographyEconomics', b'MathematicsPhysicsMedicine', b'PhysicsEngineeringComputer', b'GeographyComputer', b'SociologyChemistry', b'EngineeringMedicine', b'HistoryArt', b'MathematicsEconomics', b'PhysicsMathematics', b'MedicineBusiness', b'ArtSociology', b'MathematicsPhysics', b'HistoryMathematics', b'PsychologyMedicineComputer', b'ArtComputer', b'BiologyHistory', b'GeologyPhysics', b'EconomicsEngineering', b'BusinessComputer', b'HistoryComputer', b'GeographyChemistry', b'GeologyComputer', b'EngineeringBusiness', b'PsychologyHistory', b'HistoryMedicineComputer', b'SociologyHistory', b'SociologyPolitical', b'GeologyEngineering', b'EngineeringMathematicsComputer', b'BiologyComputer', b'SociologyEconomics', b'ArtEngineering', b'MedicineChemistryEnvironmental', b'HistoryEngineering', b'EngineeringMaterials', b'PhilosophyArt', b'ArtHistory', b'PsychologySociology', b'MedicineEngineeringComputer', b'MathematicsMedicineComputer', b'PsychologyMedicineChemistry', b'MathematicsPolitical', b'MedicineGeography', b'PsychologyEngineering', b'MedicinePhysicsComputer', b'SociologyMathematics', b'MathematicsBiologyComputer', b'EconomicsComputer', b'EngineeringBusinessComputer', b'ChemistryBiologyPhysicsComputer', b'EconomicsBusiness', b'BiologyArt', b'GeographySociology', b'ArtGeology', b'MathematicsMaterials', b'EngineeringArt', b'GeographyHistory', b'PhysicsChemistry', b'MathematicsEngineeringComputer', b'PhilosophyComputer', b'PsychologyBiology', b'ChemistryBiology', b'EconomicsPsychologyComputer', b'EconomicsPsychology', b'PhilosophyHistory', b'MedicinePolitical', b'MedicineEconomics', b'BiologyChemistryMedicine', b'SociologyPsychology', b'SociologyArt', b'MedicinePhysicsBiologyChemistry', b'EconomicsMedicine', b'PhysicsMathematicsComputer', b'MathematicsPsychology', b'SociologyBiology', b'PsychologyPolitical', b'BiologyEnvironmental', b'MedicineArt', b'EconomicsMathematicsComputer', b'BusinessEconomics', b'MedicineEnvironmental', b'HistoryMedicine', b'GeographyMaterials', b'MathematicsPhysicsComputer', b'BusinessMedicine', b'ArtPhilosophy', b'SociologyGeographyComputer', b'EngineeringBusinessMedicine', b'BiologyMathematics', b'EngineeringHistory', b'PsychologyMathematics', b'ChemistryEngineering', b'MedicinePhilosophy', b'PsychologyPhysics', b'BusinessPolitical', b'EngineeringPhysicsComputer', b'BiologyMedicineComputer', b'GeographyMathematicsEngineering', b'EngineeringBiology', b'PhysicsPolitical', b'EconomicsEngineeringComputer', b'GeographyArt', b'MedicineGeology', b'GeologyEnvironmental', b'PsychologyEconomicsComputer', b'BiologyEngineering', b'EngineeringEnvironmental', b'ArtMaterials', b'GeographyGeology', b'GeographyEngineeringComputer', b'PhysicsPsychology', b'PsychologyBusiness', b'MathematicsArt', b'MathematicsChemistry', b'PhilosophyMedicine', b'SociologyEngineering', b'PsychologyEconomics', b ...

# %%
word_embeddings = [WordEmbeddings('glove'), FlairEmbeddings('news-forward-fast'), FlairEmbeddings('news-backward-fast')]

# %%
document_embeddings = DocumentLSTMEmbeddings(word_embeddings, hidden_size=512, reproject_words=True, reproject_words_dimension=256)

# %%
# Single label for the current dataset, maybe multi-label in the future?
classifier = TextClassifier(document_embeddings, label_dictionary=corpus.make_label_dictionary(), multi_label=False)
# Out:
# 2020-04-09 11:43:00,062 Computing label dictionary. Progress:
# 100%|████████████████████████████████████████████████████████████████████████| 44666/44666 [00:00<00:00, 255918.08it/s]
# 2020-04-09 11:43:00,294 [b'Mathematics', b'Computer', b'Business', b'Materials', b'Geology', b'Art', b'Geography', b'Medicine', b'Psychology', b'Engineering', b'Biology', b'History', b'Environmental', b'Philosophy', b'EngineeringComputer', b'SociologyPhilosophy', b'Economics', b'Sociology', b'Political', b'Chemistry', b'ChemistryMedicine', b'Physics', b'PsychologyMedicine', b'MathematicsComputer', b'BiologyMedicine', b'GeographyMedicine', b'MedicineComputer', b'MedicineChemistry', b'MedicineEngineering', b'MedicineMathematicsComputer', b'MathematicsEngineering', b'SociologyMedicine', b'SociologyComputer', b'MedicinePhysics', b'PhysicsMedicine', b'PhysicsComputer', b'ChemistryPhysics', b'MedicineBiology', b'SociologyGeography', b'EconomicsMathematics', b'SociologyMedicineComputer', b'MedicineMathematics', b'MathematicsMedicine', b'PsychologyComputer', b'MedicineMaterials', b'EconomicsGeography', b'EngineeringGeography', b'EngineeringMathematics', b'GeologyMedicine', b'PsychologyArt', b'ChemistryComputer', b'GeographyEngineering', b'GeographyBiology', b'EconomicsPolitical', b'PhysicsEngineering', b'BusinessMathematics', b'GeologyGeography', b'GeographyEconomics', b'MathematicsPhysicsMedicine', b'PhysicsEngineeringComputer', b'GeographyComputer', b'SociologyChemistry', b'EngineeringMedicine', b'HistoryArt', b'MathematicsEconomics', b'PhysicsMathematics', b'MedicineBusiness', b'ArtSociology', b'MathematicsPhysics', b'HistoryMathematics', b'PsychologyMedicineComputer', b'ArtComputer', b'BiologyHistory', b'GeologyPhysics', b'EconomicsEngineering', b'BusinessComputer', b'HistoryComputer', b'GeographyChemistry', b'GeologyComputer', b'EngineeringBusiness', b'PsychologyHistory', b'HistoryMedicineComputer', b'SociologyHistory', b'SociologyPolitical', b'GeologyEngineering', b'EngineeringMathematicsComputer', b'BiologyComputer', b'SociologyEconomics', b'ArtEngineering', b'MedicineChemistryEnvironmental', b'HistoryEngineering', b'EngineeringMaterials', b'PhilosophyArt', b'ArtHistory', b'PsychologySociology', b'MedicineEngineeringComputer', b'MathematicsMedicineComputer', b'PsychologyMedicineChemistry', b'MathematicsPolitical', b'MedicineGeography', b'PsychologyEngineering', b'MedicinePhysicsComputer', b'SociologyMathematics', b'MathematicsBiologyComputer', b'EconomicsComputer', b'EngineeringBusinessComputer', b'ChemistryBiologyPhysicsComputer', b'EconomicsBusiness', b'BiologyArt', b'GeographySociology', b'ArtGeology', b'MathematicsMaterials', b'EngineeringArt', b'GeographyHistory', b'PhysicsChemistry', b'MathematicsEngineeringComputer', b'PhilosophyComputer', b'PsychologyBiology', b'ChemistryBiology', b'EconomicsPsychologyComputer', b'EconomicsPsychology', b'PhilosophyHistory', b'MedicinePolitical', b'MedicineEconomics', b'BiologyChemistryMedicine', b'SociologyPsychology', b'SociologyArt', b'MedicinePhysicsBiologyChemistry', b'EconomicsMedicine', b'PhysicsMathematicsComputer', b'MathematicsPsychology', b'SociologyBiology', b'PsychologyPolitical', b'BiologyEnvironmental', b'MedicineArt', b'EconomicsMathematicsComputer', b'BusinessEconomics', b'MedicineEnvironmental', b'HistoryMedicine', b'GeographyMaterials', b'MathematicsPhysicsComputer', b'BusinessMedicine', b'ArtPhilosophy', b'SociologyGeographyComputer', b'EngineeringBusinessMedicine', b'BiologyMathematics', b'EngineeringHistory', b'PsychologyMathematics', b'ChemistryEngineering', b'MedicinePhilosophy', b'PsychologyPhysics', b'BusinessPolitical', b'EngineeringPhysicsComputer', b'BiologyMedicineComputer', b'GeographyMathematicsEngineering', b'EngineeringBiology', b'PhysicsPolitical', b'EconomicsEngineeringComputer', b'GeographyArt', b'MedicineGeology', b'GeologyEnvironmental', b'PsychologyEconomicsComputer', b'BiologyEngineering', b'EngineeringEnvironmental', b'ArtMaterials', b'GeographyGeology', b'GeographyEngineeringComputer', b'PhysicsPsychology', b'PsychologyBusiness', b'MathematicsArt', b'MathematicsChemistry', b'PhilosophyMedicine', b'SociologyEngineering', b'PsychologyEconomics', b ...

# %%
# print(corpus.obtain_statistics())

# %%
trainer = ModelTrainer(classifier, corpus)

# %%
trainer.train('/content/drive/My Drive/Flair Text Classification/model/', max_epochs=10, embeddings_storage_mode='cpu')
# Out:
# 2020-04-09 11:43:00,338 ----------------------------------------------------------------------------------------------------
# 2020-04-09 11:43:00,340 Model: "TextClassifier(
#   (document_embeddings): DocumentLSTMEmbeddings(
#     (embeddings): StackedEmbeddings(
#       (list_embedding_0): WordEmbeddings('glove')
#       (list_embedding_1): FlairEmbeddings(
#         (lm): LanguageModel(
#           (drop): Dropout(p=0.25, inplace=False)
#           (encoder): Embedding(275, 100)
#           (rnn): LSTM(100, 1024)
#           (decoder): Linear(in_features=1024, out_features=275, bias=True)
#         )
#       )
#       (list_embedding_2): FlairEmbeddings(
#         (lm): LanguageModel(
#           (drop): Dropout(p=0.25, inplace=False)
#           (encoder): Embedding(275, 100)
#           (rnn): LSTM(100, 1024)
#           (decoder): Linear(in_features=1024, out_features=275, bias=True)
#         )
#       )
#     )
#     (word_reprojection_map): Linear(in_features=2148, out_features=256, bias=True)
#     (rnn): GRU(256, 512)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Linear(in_features=512, out_features=180, bias=True)
#   (loss_function): CrossEntropyLoss()
#   (beta): 1.0
#   (weights): None
#   (weight_tensor) None
# )"
# 2020-04-09 11:43:00,342 ----------------------------------------------------------------------------------------------------
# 2020-04-09 11:43:00,343 Corpus: "Corpus: 44666 train + 14889 dev + 14889 test sentences"
# 2020-04-09 11:43:00,344 ----------------------------------------------------------------------------------------------------
# 2020-04-09 11:43:00,346 Parameters:
# 2020-04-09 11:43:00,347  - learning_rate: "0.1"
# 2020-04-09 11:43:00,348  - mini_batch_size: "32"
# 2020-04-09 11:43:00,349  - patience: "3"
# 2020-04-09 11:43:00,350  - anneal_factor: "0.5"
# 2020-04-09 11:43:00,353  - max_epochs: "10"
# 2020-04-09 11:43:00,355  - shuffle: "True"
# 2020-04-09 11:43:00,357  - train_with_dev: "False"
# 2020-04-09 11:43:00,358  - batch_growth_annealing: "False"
# 2020-04-09 11:43:00,367 ----------------------------------------------------------------------------------------------------
# 2020-04-09 11:43:00,368 Model training base path: "\content\drive\My Drive\Flair Text Classification\model"
# 2020-04-09 11:43:00,370 ----------------------------------------------------------------------------------------------------
# 2020-04-09 11:43:00,371 Device: cpu
# 2020-04-09 11:43:00,372 ----------------------------------------------------------------------------------------------------
# 2020-04-09 11:43:00,373 Embeddings storage mode: cpu
# 2020-04-09 11:43:00,381 ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Making predictions

# %%
from flair.models import TextClassifier
from flair.data import Sentence

# %%
classifer = TextClassifier.load('/content/drive/My Drive/Flair Text Classification/model/best-model.pt')

# %% [markdown]
# Predictions are done on sentences that have no label

# %%
tcDataOther.dataNoLabel.tail(10)

# %%
sentenceWithoutLabel = tcDataOther.dataNoLabel['text'].iloc[-3]

# %%
# sentenceWithoutLabel = 'Textile Based Organic Light Emitting Diodes for Wearable Displays'

# %%
# sentenceWithoutLabel = tcDataCS.data['text'].iloc[4]

# %%
print(f'Predicting label for {sentenceWithoutLabel}')

# %%
sentence = Sentence(sentenceWithoutLabel)

# %%
classifier.predict(sentence)

# %%
print(sentence.labels)

# %%
# help(sentence)

# %%
tcDataOther.dataNoLabel['pred_label'] = ''

# %%
from tqdm import tqdm

# %%
# iterate over data without labels, make and save predictions.
for index, row in tqdm(tcDataOther.dataNoLabel.iterrows()):
  sentence = Sentence(row['text'])
  classifier.predict(sentence)
  tcDataOther.dataNoLabel.at[index, 'pred_label'] = sentence.labels

# %%
# extracting label class and probability from predicted label
tcDataOther.dataNoLabel['pred_label_class'] = ''
tcDataOther.dataNoLabel['pred_label_proba'] = ''
for index, row in tcDataOther.dataNoLabel.iterrows():
  tcDataOther.dataNoLabel.at[index, 'pred_label_class'] = str(tcDataOther.dataNoLabel['pred_label'].loc[index][0]).split(' ')[0]
  tcDataOther.dataNoLabel.at[index, 'pred_label_proba'] = re.sub('\(|\)', '', str(tcDataOther.dataNoLabel['pred_label'].loc[index][0]).split(' ')[1])

# %%
tcDataOther.dataNoLabel.head(10)

# %%
tcDataOther.dataNoLabel.to_csv('/content/drive/My Drive/Flair Text Classification/data/tcDataOtherLabelled.csv')
