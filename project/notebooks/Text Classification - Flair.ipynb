# %% [markdown]
# # Text Classification

# %% [markdown]
# 1. Use labelled datasets to predict unlabelled datasets
# 2. Need to concatenate labels together where there are multiple fields of study

# %%
import pandas as pd
import re
import numpy as np

# %% [raw]
# import ast
# test = "['computer science', 'material science', 'biology']"
# test = ast.literal_eval(test)
# len(test)

# %%
class Data():
    
    def __init__(self, fileName, fosLabel):
        
        self.dataOriginal = pd.read_csv(fileName)
        self.data = self.dataOriginal.copy()
        self.fosLabel = fosLabel
        self.lenOriginalData = len(self.data)
        
        # exe
        self.formatData()
        self.formatLabelData()
        self.dropNanText()
        self.removeDataWithoutLabels()
    
    def formatData(self):
        # subset data for title, abstract, field of study
        self.data = self.data[['Unnamed: 0', '0', '2']]
        # rename columns
        self.data.rename(columns={'Unnamed: 0': 'Title', '0': 'Abstract', '2':'Label'}, inplace=True)
        # Replace NaN
        self.data['Abstract'] = self.data['Abstract'].replace(np.nan, '', regex=True)
        # concatenate title and abstract
        self.data['Text'] = self.data['Title'] + ' ' + self.data['Abstract']
        # Drop unnecessary columns
        self.data.drop(labels=['Title', 'Abstract'], axis=1, inplace=True)
        # change order of columns
        self.data = self.data[['Text', 'Label']]
        
        # Concatenate labels
        self.data['Label'] = self.data['Label'].apply(lambda x: self.labelConcat(x))
    
    def labelConcat(self, labelText):
        # Political Science should be made into Political-Science?
        try:
            return ''.join(ast.literal_eval(labelText))
        except:
            return ''
    
    def formatLabelData(self):
        """
        FastText format
        """
        
        # Add '__label__' to data for Flair model
        self.data['Label'] = '__label__' + self.data['Label']
        
    def dropNanText(self):
        # drop any text that is NaN
        self.data['Text'] = self.data[self.data['Text'].notna()]
        
    def dataSummary(self):
        print(f'Rows dropped: {self.lenOriginalData - len(self.data)}')
        
    def removeDataWithoutLabels(self):
        
        self.dataNoLabel = self.data[self.data['Label'] == '__label__']
        self.data = self.data[self.data['Label'] != '__label__']

# %%
tcDataCS = Data(r"C:\Users\22917746\Desktop\Semantic Scholar EDA\papers_of_interest.csv", fosLabel='CS')

# %%
tcDataCS.dataSummary()
# Out:
# Rows dropped: 0

# %%
tcDataCS.dataOriginal
# Out:
#                                             Unnamed: 0  \
# 0               Texture synthesis for digital painting
# 1    Texture analysis and artificial neural network...
# 2    Automatic generation of benchmark and test wor...
# 3                             Text Encoding Initiative
# 4    A Method of Text Classification Combining Naiv...
# ..                                                 ...
# 171  Pattern-Oriented Workflow Generation and Optim...
# 172   Texture analysis using level-crossing statistics
# 173  Text Generation: Reexamining G-TAG with Abstra...
# 174  Open Source Native XML Database Architectures ...
# 175                     UAIC Participation at AVE 2007
#
#                                                      0     1  \
# 0    The problem of digital painting is considered ...  1984
# 1    Clustered microcalcifications on X-ray mammogr...  1997
# 2    In this tutorial, we describe techniques for a...  2010
# 3                                                  NaN  2012
# 4    Text classification is one of the main issues ...  2015
# ..                                                 ...   ...
# 171  Automatic workflow generation is becoming an a...  2009
# 172  We present a novel statistical texture descrip...  2004
# 173  G-TAG is a formalism dedicated to text generat...  2014
# 174  Text-based and model-based architectures are t...  2013
# 175  Textual Entailment Recognition (RTE) is a rece...  2007
#
#                         2                                                  3  \
# 0    ['Computer Science']                                                NaN
# 1    ['Computer Science']  Neural Networks for Signal Processing VII. Pro...
# 2    ['Computer Science']                                                NaN
# 3    ['Computer Science']                                                NaN
# 4    ['Computer Science']                                                NaN
# ..                    ...                                                ...
# 171  ['Computer Science']                                             J. UCS
# 172  ['Computer Science']  Proceedings of the 17th International Conferen...
# 173  ['Computer Science']                                                NaN
# 174  ['Computer Science']  2013 15th International Conference on Advanced...
# 175  ['Computer Science']                                                NaN
#
#                                                      4   5   6
# 0    https://semanticscholar.org/paper/1e9c964d606e...  63  10
# 1    https://semanticscholar.org/paper/b283fccfdeef...   3   9
# 2    https://semanticscholar.org/paper/b56c5cac50dd...   6   8
# 3    https://semanticscholar.org/paper/4c99b00b844a...   1   1
# 4    https://semanticscholar.org/paper/195e933e65ed...   0   0
# ..                                                 ...  ..  ..
# 171  https://semanticscholar.org/paper/152204729490...   3  13
# 172  https://semanticscholar.org/paper/1fc9846ff18d...   0  14
# 173  https://semanticscholar.org/paper/2838884adbdc...   0  22
# 174  https://semanticscholar.org/paper/ab85b0f4cec9...   2   2
# 175  https://semanticscholar.org/paper/c35fad14e6b2...   0   6
#
# [176 rows x 8 columns]

# %%
tcDataCS.data
# Out:
#                                                   Text  \
# 0    Texture synthesis for digital painting The pro...
# 1    Texture analysis and artificial neural network...
# 2    Automatic generation of benchmark and test wor...
# 3                            Text Encoding Initiative
# 4    A Method of Text Classification Combining Naiv...
# ..                                                 ...
# 171  Pattern-Oriented Workflow Generation and Optim...
# 172  Texture analysis using level-crossing statisti...
# 173  Text Generation: Reexamining G-TAG with Abstra...
# 174  Open Source Native XML Database Architectures ...
# 175  UAIC Participation at AVE 2007 Textual Entailm...
#
#                          Label
# 0    __label__Computer Science
# 1    __label__Computer Science
# 2    __label__Computer Science
# 3    __label__Computer Science
# 4    __label__Computer Science
# ..                         ...
# 171  __label__Computer Science
# 172  __label__Computer Science
# 173  __label__Computer Science
# 174  __label__Computer Science
# 175  __label__Computer Science
#
# [176 rows x 2 columns]

# %%
tcDataCS.data['Text'][0]
# Out:
# 'Texture synthesis for digital painting The problem of digital painting is considered from a signal processing viewpoint, and is reconsidered as a problem of directed texture synthesis. It is an important characteristic of natural texture that detail may be evident at many scales, and the detail at each scale may have distinct characteristics. A “sparse convolution” procedure for generating random textures with arbitrary spectral content is described. The capability of specifying the texture spectrum (and thus the amount of detail at each scale) is an improvement over stochastic texture synthesis processes which are scalebound or which have a prescribed 1/f spectrum. This spectral texture synthesis procedure provides the basis for a digital paint system which rivals the textural sophistication of traditional artistic media. Applications in terrain synthesis and texturing computer-rendered objects are also shown.'

# %%
tcDataCS.data.head()
# Out:
#                                                 Text  \
# 0  Texture synthesis for digital painting The pro...
# 1  Texture analysis and artificial neural network...
# 2  Automatic generation of benchmark and test wor...
# 3                          Text Encoding Initiative
# 4  A Method of Text Classification Combining Naiv...
#
#                        Label
# 0  __label__Computer Science
# 1  __label__Computer Science
# 2  __label__Computer Science
# 3  __label__Computer Science
# 4  __label__Computer Science

# %% [markdown]
# ### Other datasets

# %%
tcDataOther = Data(r"C:\Users\22917746\Desktop\Semantic Scholar EDA\papers_NOT_of_interest.csv", "Other")

# %%
tcDataOther.dataSummary()
# Out:
# Rows dropped: 44

# %%
tcDataOther.dataOriginal
# Out:
#                                             Unnamed: 0  \
# 0    Use and Safety of Respiratory Medicines in Chi...
# 1    Language in Australia: Transplanted languages ...
# 2    Automatic Generation of A High-level Contact S...
# 3    Textured Thin Films of Transition Metal Dichal...
# 4    Text Mining with Support Vector Machines and N...
# ..                                                 ...
# 314  Texture Characteristics of Chips Produced by H...
# 315              Text-type conventions and translating
# 316  Origin of classis with ring-handle on the door...
# 317  Texto para discussão 6: a tecnologia da inform...
# 318     Motivatietips in tijden van economische crisis
#
#                                                      0     1  \
# 0    textabstractThe lack of appropriately authoris...  2011
# 1                                                  NaN  1991
# 2    Information of high-level, topological contact...  2007
# 3                                                  NaN  1994
# 4    The objective of this thesis is to develop eff...  2007
# ..                                                 ...   ...
# 314                                                NaN  2019
# 315                                                NaN  1997
# 316  Textual research is made on the historical ori...  2006
# 317                                                NaN  1996
# 318  textabstractVijf korte motivatietips op het ge...  2009
#
#                          2
# 0             ['Medicine']
# 1            ['Sociology']
# 2          ['Engineering']
# 3    ['Materials Science']
# 4                       []
# ..                     ...
# 314  ['Materials Science']
# 315          ['Sociology']
# 316        ['Engineering']
# 317         ['Philosophy']
# 318  ['Political Science']
#
# [319 rows x 4 columns]

# %%
print(tcDataOther.data.to_string())
# Out:
#                                                   Text                           Label
# 0    Use and Safety of Respiratory Medicines in Chi...               __label__Medicine
# 1    Language in Australia: Transplanted languages ...              __label__Sociology
# 2    Automatic Generation of A High-level Contact S...            __label__Engineering
# 3    Textured Thin Films of Transition Metal Dichal...      __label__Materials Science
# 5    Summarization of the Literatures on Human Reso...            __label__Engineering
# 6    Risk Stratification and Risk Modification in P...               __label__Medicine
# 7    Text-melody relationships: translation of Euro...             __label__Psychology
# 8    Textbooks in Greek and Latin: 2011 Supplementa...                __label__History
# 9         Textbooks and the Teaching of Fluid Inquiry             __label__Mathematics
# 10   Texture evolution during severe plastic deform...      __label__Materials Science
# 11   Integrated SCM/PDM/CRM and delivery of softwar...    __label__BusinessMathematics
# 12   Textile Supplies for Hospitals: III. The Raw M...               __label__Medicine
# 13   Textured (Tl-Bi-Pb)-1223 thick films Screen pr...                __label__Physics
# 14   Textual Silence and (Male) Homosexual Panic in...                __label__History
# 16   Textlinguistik und Literaturwissenschaft Text ...                __label__History
# 17   Textbook of Radiation Oncology Textbook of rad...               __label__Medicine
# 18                   textbook of personnel management                __label__Business
# 19                                 Texts and Subtexts              __label__Psychology
# 20   Textbook of Stroke Medicine: Less common strok...               __label__Medicine
# 23   The Metaphorical Views in English Idioms Langu...             __label__Psychology
# 24     Text and Revelation-George Fo Use of the Bible                 __label__History
# 25   Language As Identity In Language Policy Discou...      __label__Political Science
# 26   Text authenticity in international reading lit...              __label__Sociology
# 27   Multi-Dimensional Culture of Mentoring for Nur...               __label__Medicine
# 28   Texture-Based Identification of Inert-Maceral ...      __label__Materials Science
# 29   Automatic generation of relevant mesomeric str...              __label__Chemistry
# 31                 Texts, Lies, and Changed Positions              __label__Psychology
# 32   Texte zur Geschichte des römischen und kanonis...                    __label__Art
# 33   Poverty and Business : Max Havelaar Lecture 20...      __label__Political Science
# 34   Reports from the Smithsonian’s Global Volcanis...                __label__Geology
# 35   Texture Feature Variability in Ultrasound Vide...               __label__Medicine
# 36   Textural and geochemical characteristics of th...                __label__Geology
# 37                          Textbook of Skin Diseases                __label__Medicine
# 38   TEXTURAL CHANGES IN PRECOOKED LOBSTER (Homarus...              __label__Chemistry
# 39   Texture and cross-sectional microstructure of ...      __label__Materials Science
# 40   Automatic Grid and Element Generation for Two ...            __label__Mathematics
# 41           Textile vee antena made with PVD process             __label__Engineering
# 42   Gene Expression Profiling of Soft and Firm Atl...        __label__MedicineBiology
# 43   Texts and Contexts in Classic Maya Warfare: A ...                    __label__Art
# 45   Green Alternatives to Synthetic Antioxidants, ...      __label__ChemistryMedicine
# 46   Automatic generation of transitional meshes Ad...            __label__Mathematics
# 48   Textures and Newtonian gravity Newtonian theor...                __label__Physics
# 49            Textbook of special veterinary surgery.                __label__Medicine
# 50   Texting protected health information in health...               __label__Medicine
# 51   Textbook of Orthopaedic Medicine. Vol. I, Diag...               __label__Medicine
# 52   Textile construction and air sac and air belt ...      __label__Materials Science
# 53   Textbook of the neurogenic bladder : adults an...               __label__Medicine
# 54   Conférence sans titre (1944) Texte issu de Con...                __label__History
# 55   Texture in die‐upset Nd‐Fe‐B magnet produced u...              __label__Chemistry
# 56   Palestinian State Maps and Imperial Technologi...              __label__Sociology
# 57          Texturizers in Convenience Fish Products.                 __label__Biology
# 59   Experimental Study on Mechanicial Properties o...      __label__Materials Science
# 60   Textbook of Neural Repair and Rehabilitation: ...             __label__Psychology
# 61   Identification and Modulation of Drug Resistan...                __label__Biology
# 62   Treatment modalities in experimentally induced...               __label__Medicine
# 63   Textbook language, ideology and citizenship: T...              __label__Sociology
# 64                  Textbook of bryology / P.R. Yadav                 __label__History
# 65   Semantic processing in the production of numer...     __label__PsychologyMedicine
# 66           Texture Studies on Magnesium Alloy Tubes       __label__Materials Science
# 68                             Textbook on Psychiatry              __label__Psychology
# 69   Language level and nonverbal social-communicat...     __label__PsychologyMedicine
# 70   System Aspects of Surface Acoustic Wave Convol...            __label__Engineering
# 72              Text - Stefnir Þorgilsson, Lausavísur               __label__Sociology
# 73                Textile plants wastewater treatment             __label__Engineering
# 74   Text as Topos in Religious Literature of the S...                __label__History
# 246  The Role of LRRK2 in Parkinso Disease textabst...                __label__Biology
# 247  Textural and Mineralogical Characterization of...                __label__Geology
# 249  Testimony of Representative Barbara Jordan Bef...      __label__Political Science
# 250  Impact of Signaling and Plasticity on Cerebell...             __label__Psychology
# 251                            Textes arabes de Rabat                 __label__History
# 252  Semantic and phonological loop effects on verb...     __label__PsychologyMedicine
# 253        Texto Refundido de Régimen Local: Art. 233                     __label__Art
# 255  Textual Research to the New-Style Education of...              __label__Geography
# 256  Language conflict and language planning in Ire...      __label__Political Science
# 257     Text-Mining in Business Schools: A Case Study               __label__Sociology
# 258  Texting, tweeting, and talking: Effects of sma...              __label__Sociology
# 259  Language processing during natural sleep in a ...     __label__PsychologyMedicine
# 260  Textural Transition and Genetic Relationship b...              __label__Chemistry
# 261  Textual Studies in Ancient and Medieval Geometry              __label__Philosophy
# 262                             Textos de intervenção               __label__Sociology
# 264  Language Performance of Roma Children in a Lan...              __label__Sociology
# 265  TEXTO DIDÁCTICO UNIVERSITARIO: PROPUESTAS CONS...                    __label__Art
# 266  Textkritische Bemerkungen Zu Den Synchronismen...             __label__Philosophy
# 267  Mental Health Problems and Barriers to Service...             __label__Psychology
# 268  Texture Unit, Texture Spectrum, And Texture An...            __label__Mathematics
# 269  A New Texture Descriptor Based on Local Fourie...            __label__Mathematics
# 270  Textual Healing: Claiming Black Wome Bodies, t...                __label__History
# 271                Texto y crítica de Walter Benjamin              __label__Philosophy
# 272  A Design Research Program for Textiles and Com...            __label__Engineering
# 273  Texture Characteristics of Austenitic Areas of...      __label__Materials Science
# 274  Texts and Textiles: Jane Auste Gifts to Cather...              __label__Sociology
# 275  Language Socialisation and Language Shift in t...             __label__Psychology
# 276  Information Retrieval for Simulation Debriefin...             __label__Psychology
# 277                   Textbook of Infectious Diseases                __label__Medicine
# 278  Textualism and Transnational Securities Law: A...      __label__Political Science
# 279  Language for God and Feminist Language: Proble...             __label__Philosophy
# 280  Texture Formation of Very Thin TiN, TiCN and T...      __label__Materials Science
# 281  Textbook of Military Medicine. Part 1. Warfare...            __label__Engineering
# 282  Texture Studies on Borocarbide Thin Films Epit...      __label__Materials Science
# 283  Language onset and concomitant speech and lang...     __label__PsychologyMedicine
# 284                          Textile treatment agents             __label__Engineering
# 285  Removal of pH, TDS, TSS & Color from Textile E...  __label__Environmental Science
# 286  Natural language and universal grammar: In def...             __label__Psychology
# 287  Textilchemische erfindungen. By Dr. A. Lehne. ...              __label__Chemistry
# 288  Textbook of Gastroenterology, vols 1 & 2 Textb...               __label__Medicine
# 289  Texturanalyse der Cervix uteri im B-Bild bei S...               __label__Medicine
# 290                      Texture the name of the game                     __label__Art
# 291  Texture of the surficial sediments in Fishers ...                __label__Geology
# 292  Text, cases and materials on European Union la...      __label__Political Science
# 293  Textural differentiation in chronosequences fr...                __label__Geology
# 294          Textile treatment method and composition       __label__Materials Science
# 296  Language Policies in Uruguay and Uruguayan Sig...             __label__Psychology
# 297  Global Education Greenhouse: Constructing and ...      __label__Political Science
# 298  Social Influences on Individual Decision Makin...              __label__Sociology
# 299  Textbook of Neural Repair and Rehabilitation: ...             __label__Psychology
# 300  Textilfunde aus einem Brunnen auf dem Schrange...            __label__Engineering
# 301  Textural improvement of salt-reduced Alaska po...      __label__MedicineChemistry
# 302  Text messaging to support off-campus clinical ...               __label__Medicine
# 304  Rights, politics and power: the struggle over ...      __label__Political Science
# 305  Texture induced plastic anisotropy of NiAl pol...      __label__Materials Science
# 306  Texto Refundido de Régimen Local: Disposición ...               __label__Medicine
# 307  Textbook of Parasitology Beldin Textbook of Pa...               __label__Medicine
# 308  Textbook of Me Health and Aging of the Knee, d...               __label__Medicine
# 309  Textbook of Hematology Structure and function ...               __label__Medicine
# 310  Textural evolution of nanostructured AA5083 pr...      __label__Materials Science
# 311  Natural language as a tool for analyzing the p...             __label__Psychology
# 312  Stress-reactivity in the Dutch hypertension an...               __label__Medicine
# 313  Text-book of anatomy / ed. by D. J. Cunningham...                    __label__Art
# 314  Texture Characteristics of Chips Produced by H...      __label__Materials Science
# 315             Text-type conventions and translating               __label__Sociology
# 316  Origin of classis with ring-handle on the door...            __label__Engineering
# 317  Texto para discussão 6: a tecnologia da inform...             __label__Philosophy
# 318  Motivatietips in tijden van economische crisis...      __label__Political Science

# %%
tcDataOther.lenOriginalData
# Out:
# 319

# %%
len(tcDataOther.data)
# Out:
# 275

# %%
len(tcDataOther.dataNoLabel)
# Out:
# 44

# %%
tcDataOther.dataNoLabel
# Out:
#                                                   Text      Label
# 4    Text Mining with Support Vector Machines and N...  __label__
# 15   Textschicksale: Das Werk Arthur Schnitzlers im...  __label__
# 21   Texture evolution and Swift effect in NiAl NiA...  __label__
# 22   Text-Kultur Kommunikation : Translation als Fo...  __label__
# 30   Textual Features from Multimedia Conten Identi...  __label__
# 44   Language contact and language change – linguis...  __label__
# 47   Compositional Pre-Training for Semantic Parsin...  __label__
# 58   Contextual Acquisition of Information Categori...  __label__
# 67   A PILOT STUDY IN AN APPLICATION OF TEXT MINING...  __label__
# 71   Texte, Gattungen, Textsorten und ihre Verwendu...  __label__
# 86   Textured Image Synthesis and Segmentation via ...  __label__
# 94                 TEXT 5 Aus: J.-P. Sartre, Les mots   __label__
# 96   Formal Foundations of Metamodeling : Abstract ...  __label__
# 97                           Textile Research Journal   __label__
# 115  A Review of Text Mining and Knowledge Discover...  __label__
# 116  Text 7: „Pflichtmäsiger Vortrag die Berufung d...  __label__
# 121                Texte und Kontexte des Sirachbuchs   __label__
# 124  Text (non-literar) si actiune Texte (non litté...  __label__
# 127  Semantic Process Models In today’s fast changi...  __label__
# 128  Automatic Generation ControlA Review Automatic...  __label__
# 131    Textile Technology at Leeds: Dr. C. S. Whewell   __label__
# 137               Language Death or Language Suicide?   __label__
# 140  A Breakaway from the Ritual of Two Dimensional...  __label__
# 146  Textsemantik des Spielfilms : zum Ausdruckspot...  __label__
# 167  tScore : Making Computers and Humans Talk abou...  __label__
# 179  Texture and fabric characteristics of atmosphe...  __label__
# 184  Textbearbetning och textåtervinning i teori oc...  __label__
# 188       Textbooks: What Exists and What Do We Need?   __label__
# 197                     Text-Book of Nervous Diseases   __label__
# 201                                     Text. Part 2.   __label__
# 212  Automatic College Timetable Generation 521 Aut...  __label__
# 217  Text-book on Practical Astronomy THE professed...  __label__
# 218  Texture Gradient from Images for Segmentation ...  __label__
# 228  Text Entailment and Machine Translation Evalua...  __label__
# 232  Text Mining Preprocessing In Times of Python v...  __label__
# 233  Textprobleme in Augustinus, De Genesi contra M...  __label__
# 237  Dynamic Texture Coding using Modified Haar Wav...  __label__
# 240  Language acquisition and the architecture of t...  __label__
# 244  Textos Intermidiáticos na Literatura Infanto-J...  __label__
# 248  Automatic Patch Generation Current static code...  __label__
# 254  Texts and Icons in Heidegger’s Metaphysical Tr...  __label__
# 263                   Texter kring Daniel från Sketis   __label__
# 295  Textos y contextos sobre solidaridad/voluntari...  __label__
# 303  Text als Herausforderung: zur Textkompetenz am...  __label__

# %% [markdown]
# ### Create entire dataset

# %%
trainingData = tcData.data.append(tcDataOther.data)

# %%
trainingData
# Out:
#                                                   Text  \
# 0    Texture synthesis for digital painting The pro...
# 1    Texture analysis and artificial neural network...
# 2    Automatic generation of benchmark and test wor...
# 3                            Text Encoding Initiative
# 6    A Method of Text Classification Combining Naiv...
# ..                                                 ...
# 314  Texture Characteristics of Chips Produced by H...
# 315             Text-type conventions and translating
# 316  Origin of classis with ring-handle on the door...
# 317  Texto para discussão 6: a tecnologia da inform...
# 318  Motivatietips in tijden van economische crisis...
#
#                           Label
# 0     __label__Computer Science
# 1     __label__Computer Science
# 2     __label__Computer Science
# 3     __label__Computer Science
# 6     __label__Computer Science
# ..                          ...
# 314  __label__Materials Science
# 315          __label__Sociology
# 316        __label__Engineering
# 317         __label__Philosophy
# 318  __label__Political Science
#
# [432 rows x 2 columns]

# %% [markdown]
# #### Test, Dev, Train Split

# %%
# attr: https://stackoverflow.com/questions/38250710/how-to-split-data-into-3-sets-train-validation-and-test
train, dev, test = np.split(trainingData.sample(frac=1), [int(.6*len(trainingData)), int(.8*len(trainingData))])
print(f'{len(trainingData)} | {len(train)} | {len(dev)} | {len(test)}')
# Out:
# 432 | 259 | 86 | 87

# %%
train.to_csv(r'ml_data/train.csv')
test.to_csv(r'ml_data/test.csv')
dev.to_csv(r'ml_data/dev.csv')

# %% [markdown]
# ## Flair Text Classification

# %% [markdown]
# https://towardsdatascience.com/text-classification-with-state-of-the-art-nlp-library-flair-b541d7add21f

# %%
from flair.data_fetcher import NLPTaskDataFetcher
from flair.embeddings import WordEmbeddings, FlairEmbeddings, DocumentLSTMEmbeddings
from flair.models import TextClassifier
from flair.trainers import ModelTrainer
from pathlib import Path

# %%
corpus = NLPTaskDataFetcher.load_classification_corpus(Path('./ml_data'), test_file='test.csv', dev_file='dev.csv', train_file='train.csv')
# Out:
# 2020-04-08 06:35:45,868 Reading data from ml_data
# 2020-04-08 06:35:45,869 Train: ml_data\train.csv
# 2020-04-08 06:35:45,870 Dev: ml_data\dev.csv
# 2020-04-08 06:35:45,871 Test: ml_data\test.csv
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function (or staticmethod) load_classification_corpus. (Use 'flair.datasets' instead.) -- Deprecated since version 0.4.1.
#   """Entry point for launching an IPython kernel.
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\data_fetcher.py:452: DeprecationWarning: Call to deprecated function (or staticmethod) read_text_classification_file. (Use 'flair.datasets' instead.) -- Deprecated since version 0.4.1.
#   train_file, tokenizer=tokenizer, max_tokens_per_doc=max_tokens_per_doc
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\data_fetcher.py:457: DeprecationWarning: Call to deprecated function (or staticmethod) read_text_classification_file. (Use 'flair.datasets' instead.) -- Deprecated since version 0.4.1.
#   test_file, tokenizer=tokenizer, max_tokens_per_doc=max_tokens_per_doc
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\data_fetcher.py:464: DeprecationWarning: Call to deprecated function (or staticmethod) read_text_classification_file. (Use 'flair.datasets' instead.) -- Deprecated since version 0.4.1.
#   dev_file, tokenizer=tokenizer, max_tokens_per_doc=max_tokens_per_doc

# %%
word_embeddings = [WordEmbeddings('glove'), FlairEmbeddings('news-forward-fast'), FlairEmbeddings('news-backward-fast')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-239-0796eb08bb2b> in <module>
# ----> 1 word_embeddings = [WordEmbeddings('glove'), FlairEmbeddings('news-forward-fast'), FlairEmbeddings('news-backward-fast')]
#
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\embeddings.py in __init__(self, model, fine_tune, chars_per_chunk)
#    1986             self.name = f"Task-LSTM-{self.lm.hidden_size}-{self.lm.nlayers}-{self.lm.is_forward_lm}"
#    1987         else:
# -> 1988             self.lm: LanguageModel = LanguageModel.load_language_model(model)
#    1989             self.name = str(model)
#    1990
#
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\models\language_model.py in load_language_model(cls, model_file)
#     195             state["embedding_size"],
#     196             state["nout"],
# --> 197             state["dropout"],
#     198         )
#     199         model.load_state_dict(state["state_dict"])
#
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\models\language_model.py in __init__(self, dictionary, is_forward_lm, hidden_size, nlayers, embedding_size, nout, dropout)
#      59
#      60         # auto-spawn on GPU if available
# ---> 61         self.to(flair.device)
#      62
#      63     def init_weights(self):
#
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\torch\nn\modules\module.py in to(self, *args, **kwargs)
#     423             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     424
# --> 425         return self._apply(convert)
#     426
#     427     def register_backward_hook(self, hook):
#
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\models\language_model.py in _apply(self, fn)
#     392     def _apply(self, fn):
#     393         major, minor, build, *_ = (int(info)
# --> 394                                 for info in torch.__version__.split('.'))
#     395
#     396         # fixed RNN change format for torch 1.4.0
#
# c:\users\22917746\appdata\local\programs\python\python36\lib\site-packages\flair\models\language_model.py in <genexpr>(.0)
#     392     def _apply(self, fn):
#     393         major, minor, build, *_ = (int(info)
# --> 394                                 for info in torch.__version__.split('.'))
#     395
#     396         # fixed RNN change format for torch 1.4.0
#
# ValueError: invalid literal for int() with base 10: '0+cpu'

# %%
document_embeddings = DocumentLSTMEmbeddings(word_embeddings, hidden_size=512, reproject_words=True, reproject_words_dimension=256)

# %%
classifier = TextClassifier(document_embeddings, label_dictionary=corpus.make_label_dictionary(), multi_label=False)

# %%
trainer = ModelTrainer(classifier, corpus)

# %%
trainer.train('./', max_epochs=10)
